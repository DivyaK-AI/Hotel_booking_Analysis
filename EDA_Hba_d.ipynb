# %% [markdown]
# # Project Name :-

# %% [markdown]
# Project Type - EDA Contribution - Individual Name: Divya Kumari

# %% [markdown]
# # Project Summary :-

# %% [markdown]
# The hotel booking dataset comprises diverse attributes providing insight into booking behavior and guest preferences in the hospitality industry. Analyzing this data allows for a comprehensive understanding of various aspects influencing hotel bookings.
#
# Booking Trends:
# The dataset delineates booking trends by capturing parameters such as lead time, arrival date, and the duration of stays, including weekends and weekdays. This information aids in identifying seasonal booking patterns and trends in the length of stay.
#
# Guest Demographics:
# Insight into the demographics of guests is facilitated by the counts of adults, children, and babies in bookings. Further, the country of origin data provides valuable information about the guests' geographic distribution.
#
# Booking Details:
# Meal preferences, room types, and special requests indicate customer preferences and expectations regarding accommodations and services. Additionally, the dataset includes data on booking changes, previous cancellations, and deposit types, shedding light on booking modifications and payment practices.
#
# Operational Insights:
# Features like distribution channels, customer types, and average daily rates (ADR) provide operational insights. It helps in understanding the sources of bookings, customer segmentation, and average revenue generated per occupied room, aiding revenue management strategies.
#
# Cancellation Analysis:
# is_canceled, previous_cancellations, and reservation_status offer valuable data on booking cancellations and reservation statuses. This information is crucial for managing overbooking scenarios and optimizing room occupancy.
#
# Service Optimization:
# Features like parking space requirements and special requests reflect the additional services guests seek, enabling hotels to improve service quality and guest experience.
#
# Industry Performance Metrics:
# The dataset's rich information can assist in analyzing industry performance, such as examining the market segments contributing most to bookings and revenue.
#
# In conclusion, the dataset provides a holistic view of hotel bookings, encompassing diverse aspects such as booking behavior, guest demographics, preferences, and operational aspects. Analyzing this dataset can empower hotel management to make informed decisions regarding marketing strategies, service enhancements, revenue management, and optimizing customer satisfaction.

# %% [markdown]
# #GitHub Link -

# %% [markdown]
# #Problem Statement:-

# %% [markdown]
# Here are a few problem statements that could be addressed using hotel booking data:
#
# Demand Forecasting: Predicting future bookings to optimize resource allocation and staffing levels.
#
# Cancellation Prediction: Identifying factors leading to cancellations to reduce revenue loss.
#
# Guest Segmentation: Segregating guests based on behavior for personalized marketing and services.
#
# Pricing Optimization: Determining ideal pricing strategies to maximize revenue.
# Customer Retention: Analyzing patterns to improve customer satisfaction and loyalty programs.
#
# Channel Performance: Assessing the effectiveness of different booking channels for better resource allocation.
#
# Seasonal Analysis: Understanding seasonal variations to tailor offerings and marketing campaigns accordingly.
#
# Competitive Benchmarking: Comparing performance metrics with competitors for strategic decision-making.

# %% [markdown]
# ##Define Your Business Objective?

# %% [markdown]
# The major business goal is to maximize income and guest pleasure by utilizing insights from hotel booking data. This includes fine-tuning pricing tactics, expanding service options depending on visitor preferences, and improving operational efficiency to improve the overall guest experience. The analysis attempts to improve revenue growth, operational efficiency, and customer happiness in the hotel industry.

# %% [markdown]
# #General Guidelines : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# #***Let 's Begin !***

# %% [markdown]
# #Know Your Data

# %% [markdown]
# hotel : 1)Resort Hotel 2)City Hotel).
#
# is_canceled :if the booking was canceled (1) or not canceled (0)
#
# lead_time:Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.
#
# arrival_date_year : arriving Year date
#
# arrival_date_month: arriving Month date
#
# arrival_date_week_number : Week number in year for arrival date
#
# arrival_date_day_of_month : Day of arrival date
#
# stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday)
#
# stays_in_week_nights : Number of stay in week nights i.e Monday to Friday
#
# adults : Number of adults
#
# children : Number of children
#
# babies: Number of babies
#
# meal: Type of meal preferred.
#
# Undefined/SC – no meal package
#
# BB – Bed & Breakfast
#
# HB – Half board (breakfast and one other meal)
#
# FB – Full board (breakfast, lunch and dinner)
#
# country : Country of origin
#
# market_segment : Market segment designation.
#
# TA:- Travel Agents and TO:-Tour Operators
#
# distribution_channel: Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# is_repeated_guest : The booking name was from a repeated guest (1) or not (0)
#
# previous_cancellations : Number of previous bookings that were cancelled by the customer compare to the current booking
#
# previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer compare to the current booking
#
# reserved_room_type : Code of room type reserved.
#
# assigned_room_type : Code for the type of room assigned to the booking.
#
# booking_changes : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# deposit_type: customer made a deposit to guarantee the booking. This variable can assume three categories:
#
# No Deposit – no deposit was made
#
# Non Refund - a deposit was made in the value of the total stay
#
# cost Refundable – a deposit was made with a value under the total cost of stay.
#
# agent : ID of the travel agency that made the booking
#
# company : ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
#
# days_in_waiting_list : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# customer_type : Type of booking, assuming one of four categories:
#
# Contract - when the booking has an allotment or other type of contract associated to it
#
# Group– when the booking is associated to a group
#
# Transient– when the booking is not part of a group or contract, and is not associated to other transient booking
#
# Transient-party – when the booking is transient, but is associated to at least other transient booking
#
# adr: It is measured as the total revenues generated by all the occupied rooms in a hotel or lodge divided by the total number of occupied rooms over a given time period. It is a simple average that shows the revenues generated per occupied room.
#
# The average daily rate (ADR) is a useful tool to maximize revenues in the hospitality sector. The ADR is measured as the total revenues generated by all the occupied rooms in the hotel or lodge divided by the total number of occupied rooms over a given time period. The average daily rate includes only the occupied rooms and not the total available stock. List item
#
# required_car_parking_spaces : Number of car parking spaces required by the customer
#
# *total_of_special_requests *: Number of special requests made by the customer
#
# reservation_status : Reservation last status, assuming one of three categories:
#
# Check-Out– customer has checked in but already departed
#
# No-Show – customer did not check-in and did inform the hotel of the reason
#
# reservation_status_date : Date at which the last status was set.

# %% [markdown]
# #Import *Libraries*

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Dataset Loading**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv')

# %% [markdown]
# ##Dataset First View

# %%
# Dataset First Look
df =  data.copy()
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ###Dataset Rows & Columns count

# %%
# Checking Row & Columns in Dataset.
print('Row & Columns of Hotel Booking dataset : ',df.shape)
print('\n')
# Out:
# Row & Columns of Hotel Booking dataset :  (119390, 32)

# %% [markdown]
# ###Dataset Information

# %%
# Dataset Info
df.head() #first 5rows of dataset1(by default 5rows)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Dataset Info
df.tail() # last 5rows of dataset1(by default 5rows)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.sample(10) #random 10 rows of dataset
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 31653   Resort Hotel            0        136               2016
# 112494    City Hotel            0         20               2017
# 6442    Resort Hotel            1         57               2016
# 103158    City Hotel            0          7               2017
# 57800     City Hotel            1        267               2016
# 72575     City Hotel            1        164               2017
# 89932     City Hotel            0         28               2016
# 64203     City Hotel            1         28               2017
# 41572     City Hotel            0         14               2015
# 93465     City Hotel            0         78               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 31653            December                        53
# 112494                May                        21
# 6442                 June                        24
# ...

# %% [markdown]
# ###Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().value_counts() #to find total of duplicated values
# Out:
# False    87396
# True     31994
# dtype: int64

# %% [markdown]
# ###Dropping Duplicated values

# %%
df.drop_duplicates(inplace=True) #delete duplicate value

# Re-check the duplicates if any present after droping the duplicates from data sets.

df.duplicated().value_counts()
# Out:
# False    87396
# dtype: int64

# %% [markdown]
# ###Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87392 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %%
# Finding Null Values and arrange in decending orders

null_val = df.isnull().sum().sort_values(ascending=False).head(10).reset_index().rename(columns={'index':'column',0:'count'})
null_val
# Out:
#                    column  count
# 0                 company  82137
# 1                   agent  12193
# 2                 country    452
# 3                children      4
# 4      reserved_room_type      0
# 5      assigned_room_type      0
# 6         booking_changes      0
# 7            deposit_type      0
# 8                   hotel      0
# 9  previous_cancellations      0

# %%
# Visualizing the missing values
# Heatmap to see null values in dataset

plt.figure(figsize=(20,8))
sns.heatmap(df.isnull(),cbar=False,cmap='plasma')
plt.title('Missing values display',fontsize=20)
plt.show()

# %%
df['children'].fillna(0,inplace=True)
df['agent'].fillna(0,inplace=True)
df['country'].fillna('others',inplace=True)

# %%
df.drop(['company'],axis=1,inplace=True)

# %%
df['children']=df['children'].astype(int)
df['agent']=df['agent'].astype(int)

# %%
df['total_people'] = df['adults']+df['babies']+df['children']

df['total_stay']= df['stays_in_week_nights']+df['stays_in_weekend_nights']

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.columns.tolist()
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date',
#  'total_people',
#  'total_stay']

# %%
df.shape
# Out:
# (87396, 33)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
num_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
               'required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled',
               'booking_changes']

num_plots = len(num_columns)

plt.figure(figsize=(20, 15))  # Adjust the figure size according to your preference

for i, column in enumerate(num_columns, 1):
    plt.subplot((num_plots // 3) + 1, 3, i)
    sns.boxplot(x=df[column])
    plt.xlabel(column)  # Set x-label as the column name for better clarity
    plt.tight_layout()

plt.show()

# %%
# Define upper limits for outlier capping
lead_time_limit = 500
weekend_nights_limit = 5
adults_limit = 4
previous_bookings_limit = 1
previous_cancellations_limit = 1
week_nights_limit = 10
booking_changes_limit = 5
parking_spaces_limit = 5
children_limit = 8


# Cap outliers using np.clip function
df['lead_time'] = np.clip(df['lead_time'], None, lead_time_limit)
df['stays_in_weekend_nights'] = np.clip(df['stays_in_weekend_nights'], None, weekend_nights_limit)
df['adults'] = np.clip(df['adults'], None, adults_limit)
df['previous_bookings_not_canceled'] = np.clip(df['previous_bookings_not_canceled'], None, previous_bookings_limit)
df['previous_cancellations'] = np.clip(df['previous_cancellations'], None, previous_cancellations_limit)
df['stays_in_week_nights'] = np.clip(df['stays_in_week_nights'], None, week_nights_limit)
df['booking_changes'] = np.clip(df['booking_changes'], None, booking_changes_limit)
df['required_car_parking_spaces'] = np.clip(df['required_car_parking_spaces'], None, parking_spaces_limit)
df['children'] = np.clip(df['children'], None, children_limit)

# %%
y=df[df['adr']>1000].index
y
med = df['adr'].median()
print(med)
# Out:
# 98.1

# %%
df.loc[48515,'adr'] = med
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        500               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  \
# 0                        0                     0       2  ...      0
# ...

# %%
num_columns = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
               'required_car_parking_spaces', 'adr', 'previous_cancellations', 'previous_bookings_not_canceled',
               'booking_changes']

num_plots = len(num_columns)

plt.figure(figsize=(20, 15))  # Adjust the figure size according to your preference

for i, column in enumerate(num_columns, 1):
    plt.subplot((num_plots // 3) + 1, 3, i)
    sns.boxplot(x=df[column])
    plt.xlabel(column)  # Set x-label as the column name for better clarity
    plt.tight_layout()

plt.show()

# %%
# Calculate revenue based on the specified conditions for Resort Hotel
revenue_0_resort = df[(df['hotel'] == 'Resort Hotel') & (df['is_canceled'] == 0) & ((df['deposit_type'] == 'No Deposit') | (df['deposit_type'] == 'Non Refund'))]['adr'].sum() - df[(df['hotel'] == 'Resort Hotel') & (df['is_canceled'] == 0) & (df['deposit_type'] == 'Refundable')]['adr'].sum()
revenue_1_resort = df[(df['hotel'] == 'Resort Hotel') & (df['is_canceled'] == 1) & (df['deposit_type'] == 'Non Refund')]['adr'].sum() - df[(df['hotel'] == 'Resort Hotel') & (df['is_canceled'] == 1) & (df['deposit_type'] == 'Refundable')]['adr'].sum()

# Calculate revenue based on the specified conditions for City Hotel
revenue_0_city = df[(df['hotel'] == 'City Hotel') & (df['is_canceled'] == 0) & ((df['deposit_type'] == 'No Deposit') | (df['deposit_type'] == 'Non Refund'))]['adr'].sum() - df[(df['hotel'] == 'City Hotel') & (df['is_canceled'] == 0) & (df['deposit_type'] == 'Refundable')]['adr'].sum()
revenue_1_city = df[(df['hotel'] == 'City Hotel') & (df['is_canceled'] == 1) & (df['deposit_type'] == 'Non Refund')]['adr'].sum() - df[(df['hotel'] == 'City Hotel') & (df['is_canceled'] == 1) & (df['deposit_type'] == 'Refundable')]['adr'].sum()

# Print the calculated revenues for Resort Hotel
#print("Revenue for Resort Hotel when not cancelled :", revenue_0_resort)
#print("Revenue for Resort Hotel when cancelled :", revenue_1_resort)

# Print the calculated revenues for City Hotel
#print("Revenue for City Hotel when not cancelled :", revenue_0_city)
#print("Revenue for City Hotel when cancelled : ", revenue_1_city)

# Calculate total revenue
total_revenue = revenue_0_resort + revenue_1_resort + revenue_0_city + revenue_1_city
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 6535964.63

# %% [markdown]
# # Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables

# %% [markdown]
# ###Chart - 1

# %%
# Chart - 1 visualization code
hotel_booking_counts = df['hotel'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 5))
plt.pie(hotel_booking_counts, labels=hotel_booking_counts.index, autopct='%1.1f%%',explode=[ 0.0, 0.1,],shadow =True ,startangle=90)
plt.title('Pie Chart of Hotel Booking Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ######1. Why did you pick this specific chart?

# %% [markdown]
# The pie chart was chosen to showcase the distribution of hotel booking types due to its ability to visually represent proportions effectively. Its circular format allows easy comparison between different hotel types, offering a clear visualization of the relative sizes or percentages of each category in the dataset.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals insights into the distribution of hotel bookings, indicating the relative popularity or prevalence of different hotel types. It visually highlights which hotel types are more frequently booked compared to others, providing a quick understanding of the distribution pattern among the available categories.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights indicating declining bookings for a specific hotel type may lead to negative growth due to potential issues affecting customer interest or market relevance. Conversely, understanding popular hotel types can positively impact strategies, enhancing customer satisfaction and revenue.

# %% [markdown]
# ###Chart - 2

# %%
# Chart - 2 visualization code
# cancelation and non-cancellation

canc_no_canc=df.copy()
canc_no_canc['is_canceled'] = canc_no_canc['is_canceled'].replace([1,0], ['canceled', 'not_canceled'])

canc_no_canc=canc_no_canc.groupby('is_canceled')['is_canceled'].count()
canc_no_canc
# Out:
# is_canceled
# canceled        24025
# not_canceled    63371
# Name: is_canceled, dtype: int64

# %%
# Assuming 'canc_no_canc' contains the counts for cancellation and non-cancellation

# Create data
labels = ['Cancellation', 'Non-Cancellation']
counts = [canc_no_canc['canceled'], canc_no_canc['not_canceled']]

# Create horizontal bar chart
plt.figure(figsize=(8, 5))
plt.barh(labels, counts, color=['red', 'green'])
plt.xlabel('Count')
plt.title('Cancellation vs Non-Cancellation')
plt.gca().set_facecolor('#f0f0f0')

# Display the count values on the bars
for index, value in enumerate(counts):
    plt.text(value, index, str(value), ha='left', va='center', color='black', fontweight='bold')

plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The horizontal bar chart was chosen because it provides a clear and straightforward comparison between cancellation and non-cancellation counts. Its horizontal orientation makes it easy to compare the lengths of the bars, representing the counts for each category. Additionally, the inclusion of labels and counts on the bars enhances readability, making it easier to interpret the comparison between the two categories at a glance.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart effectively illustrates the comparison between cancellation and non-cancellation counts. It offers a clear insight into the relative count or frequency of both categories, highlighting any significant differences between the two. This visualization quickly communicates the volume or frequency of cancellations compared to non-cancellations, aiding in understanding their relative proportions within the dataset.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights revealing a high cancellation rate might indicate issues affecting customer satisfaction, potentially leading to negative growth. Conversely, understanding cancellation frequencies can help strategize to reduce cancellations, positively impacting revenue by enhancing customer experience.

# %% [markdown]
# ###Chart - 3

# %%
def fun(x,y):
    if x==y:
        return True
    else:
        return False

# %%
df["prefer"] = df.apply(lambda x: fun(x.reserved_room_type,x.assigned_room_type),axis=1)

# %%
sat_count = df["prefer"].value_counts()

# Define labels and data
model = ["Satisfied", "Change of Room"]
data_sat = [sat_count[True], sat_count[False]]

# Create a pie chart
fig= plt.figure(figsize=(6, 6))  # Adjust the figure size if needed
plt.pie(data_sat, labels=model, colors=['mediumpurple', 'coral'], autopct='%1.1f%%', explode=[ 0.0, 0.1,],shadow = True, startangle=140)
plt.title("Guest Satisfaction")
fig.patch.set_facecolor('grey')

# Show the pie chart
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?
#
# The specific chart chosen is a pie chart, displaying the distribution of guest satisfaction levels based on their preferences—either being satisfied or requiring a change of room. The pie chart effectively illustrates the proportions or percentages of these two categories, providing a quick and easy-to-understand visualization of the guest satisfaction distribution.
#
# .
#
# 2. What is/are the insight(s) found from the chart?
#
# The pie chart on guest satisfaction provides insights into the distribution of satisfaction levels among guests. Specifically, it illustrates the proportion or percentage of guests who are satisfied versus those who require a change of room. This visualization offers a quick overview of the relative satisfaction levels, aiding in understanding the ratio between satisfied and dissatisfied guests in the dataset.
#
#
#
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# The insights gained from the pie chart on guest satisfaction can potentially lead to a positive business impact by helping identify areas for improvement in guest experiences. Understanding the distribution of satisfied versus dissatisfied guests can guide strategies to enhance service quality, address issues promptly, and improve overall guest satisfaction. Consequently, this could positively impact the business by fostering guest loyalty, positive reviews, and returning customers, ultimately contributing to positive growth.
#
# However, if a substantial portion of guests requires a change of room (indicating dissatisfaction), it may highlight underlying issues affecting guest experiences. Failure to address these concerns could lead to negative growth by impacting reputation, customer retention, and potential revenue loss due to dissatisfied guests seeking alternatives. Therefore, it's crucial to address any identified dissatisfaction proactively to prevent potential negative impacts on the business.
